# %% [markdown]
# #Preprocessing

# %%
import numpy as np
import pandas as pd
import io
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a44bec2a-8ee9-4510-9fd6-36abd5f20dca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a44bec2a-8ee9-4510-9fd6-36abd5f20dca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving spotify_data.csv to spotify_data.csv

# %%
# Read data into dataframe
df = pd.read_csv('spotify_data.csv')

# %%
df2 = df.copy()

# %%
df2.dtypes
# Out:
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# id                   object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# valence             float64
# year                  int64
# dtype: object

# %%
df2.head(1)
# Out:
#    acousticness              artists  danceability  ...    tempo  valence  year
# 0         0.995  ['Carl Woitschach']         0.708  ...  118.469    0.779  1928
#
# [1 rows x 19 columns]

# %%
#convert milliseconds to minutes
df2['duration_min'] = df2['duration_ms'] / 60000

# %%
df2.head(1)
# Out:
#    acousticness              artists  danceability  ...  valence  year  duration_min
# 0         0.995  ['Carl Woitschach']         0.708  ...    0.779  1928      2.644133
#
# [1 rows x 20 columns]

# %%
# generate short list describing the number of explicit and nonexplicit songs in the dataset
explicit_numbers =[df2[df2['explicit'] == 0].shape[0], df2[df2['explicit'] == 1].shape[0]]

# %% [markdown]
# #Ungrouped Features

# %% [markdown]
# In this section, features are examined without any grouping

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
explicit_values = ['Not Explicit', 'Explicit']
ax.bar(explicit_values, explicit_numbers)
ax.set_ylabel('Number of Songs')
ax.set_title('Frequency of Non Explicit and Explicit Songs')
plt.show()

# %%
plt.figure()
data = df2['acousticness']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Acousticness of Songs')
plt.show()

# %%
plt.figure()
data = df2['danceability']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Danceability of Songs')
plt.show()

# %%
data = df2['duration_min']
fig = plt.figure()
ax = fig.add_axes([0,0,3,1])
ax.boxplot(data, vert=False)
ax.set_xlabel('Number of Songs')
ax.set_title('Distribution of Song lengths in minutes')
ax.set_xticks(range(1,81,2))
plt.show()

# %%
plt.figure()
data = df2['energy']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Energy of Songs')
plt.show()

# %%
plt.figure()
data = df2['instrumentalness']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Instrumentalness of Songs')
plt.show()

# %%
keys = []
for i in range(12):
  keys.append(df2[df2['key'] == i].shape[0])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(range(12), keys)
ax.set_xticks(range(12))
ax.set_ylabel('Number of Songs')
ax.set_xticklabels(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
ax.set_title('Frequency of keys of songs')
plt.show()

# %%
plt.figure()
data = df2['liveness']
plt.hist(data, bins = 30, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Liveness of Songs')
plt.show()

# %%
plt.figure()
data = df2['loudness']
plt.hist(data, bins = 40, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Loudness of Songs')
plt.show()

# %%
mode_numbers =[df2[df2['mode'] == 0].shape[0], df2[df2['mode'] == 1].shape[0]]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
mode_values = ['Minor', 'Major']
ax.bar(mode_values, mode_numbers)
ax.set_ylabel('Number of Songs')
ax.set_title('Mode of Songs')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
data = df2['popularity']
ax.hist(data, bins = 100, rwidth = 0.8)
ax.set_ylabel('Number of Songs')
ax.set_title('Popularity Rating of Songs')
plt.show()

# %%
years = []
for i in range(1921, 2021):
  years.append(df2[df2['year'] == i].shape[0])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(range(1921,2021), years)
ax.set_ylabel('Number of Songs')
ax.set_title('Frequency of keys of songs')
plt.show()

# %%
plt.figure()
data = df2['speechiness']
plt.hist(data, bins = 15, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Speechiness of Songs')
plt.show()

# %%
plt.figure()
data = df2['tempo']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Tempo of Songs')
plt.show()

# %%
plt.figure()
data = df2['valence']
plt.hist(data, bins = 20, rwidth = 0.8)
plt.ylabel('Number of Songs')
plt.title('Valence of Songs')
plt.show()

# %% [markdown]
# # Features by Key

# %% [markdown]
# Featues are graphed grouped by key

# %%
df_key = df2.groupby(['key']).mean()
df_key
# Out:
#      acousticness  danceability  ...         year  duration_min
# key                              ...
# 0        0.508403      0.536750  ...  1976.134843      3.848629
# 1        0.427154      0.561916  ...  1981.783942      3.884125
# 2        0.472527      0.524936  ...  1977.638011      3.915883
# 3        0.669181      0.500900  ...  1968.559081      3.773294
# 4        0.467659      0.526094  ...  1978.950313      3.872604
# 5        0.573989      0.532763  ...  1973.243389      3.866342
# 6        0.432668      0.557759  ...  1981.507803      3.834613
# 7        0.491670      0.540108  ...  1976.833791      3.808188
# 8        0.534134      0.537434  ...  1976.243955      3.842681
# 9        0.440563      0.534490  ...  1978.838155      3.849984
# 10       0.559997      0.543434  ...  1974.430906      3.879463
# 11       0.388651      0.565061  ...  1981.856037      3.870572
#
# [12 rows x 15 columns]

# %%
data = df_key['explicit']
fig = plt.figure()
ax = fig.add_axes([0,0,3,1])
ax.bar(range(12), data)
ax.set_xticks(range(12))
ax.set_xticklabels(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
ax.set_ylabel('Average of Songs')
ax.set_title('Percentage of Explicit Songs by Key')
plt.show()

# %%
data = df_key['instrumentalness']
fig = plt.figure()
ax = fig.add_axes([0,0,3,1])
ax.bar(range(12), data)
ax.set_xticks(range(12))
ax.set_xticklabels(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
ax.set_ylabel('Average of Songs')
ax.set_title('Instrumentalness of Songs by Key')
plt.show()

# %%
data = df_key['loudness']
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(range(12), data)
ax.set_xticks(range(12))
ax.set_xticklabels(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
ax.set_ylabel('Average of Songs')
ax.set_title('Loudness of Songs by Key')
plt.show()

# %%
data = df_key['year']
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(range(12), data)
ax.set_xticks(range(12))
ax.set_xticklabels(['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'])
ax.set_ylabel('Average Year')
ax.set_ybound(1960,1985)
ax.set_title('Average release year of songs by key')
plt.show()

# %% [markdown]
# # Features by Explicit Label

# %% [markdown]
# Featues are graphed grouped by explicit label

# %%
df_ex = df2.groupby(['explicit']).mean()
df_ex
# Out:
#           acousticness  danceability  ...         year  duration_min
# explicit                              ...
# 0             0.522310      0.525234  ...  1975.312026      3.883746
# 1             0.179454      0.677433  ...  1997.833067      3.565864
#
# [2 rows x 15 columns]

# %%
data = df_ex['acousticness']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Acousticness of Songs by Language')
plt.show()

# %%
data = df_ex['danceability']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Danceability of Songs by Language')
plt.show()

# %%
data = df_ex['energy']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Energy of Songs by Language')
plt.show()

# %%
data = df_ex['instrumentalness']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Instrumentalness of Songs by Language')
plt.show()

# %%
data = df_ex['liveness']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Liveness of Songs')
ax.set_title('Liveness of Songs by Language')
plt.show()

# %%
data = df_ex['loudness']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Loudness of Songs by Language')
plt.show()

# %%
data = df_ex['mode']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Percentage of Major Mode Songs by Language')
plt.show()

# %%
data = df_ex['popularity']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Popularity of Songs by Language')
plt.show()

# %%
data = df_ex['speechiness']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Speechiness of Songs by Language')
plt.show()

# %%
data = df_ex['tempo']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_ybound(110,120)
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ylabel('Average of Songs')
ax.set_title('Tempo of Songs by Language')
plt.show()

# %%
data = df_ex['year']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(2), data)
ax.set_xticks(range(2))
ax.set_xticklabels(['Non-explicit', 'Explicit'])
ax.set_ybound(1970,2000)
ax.set_ylabel('Average Year of Release')
ax.set_title('Average Year of Release by Language')
plt.show()

# %% [markdown]
# # Features by Year

# %% [markdown]
# Featues are graphed grouped by year

# %%
df_year = df2.groupby(['year']).mean()
df_year
# Out:
#       acousticness  danceability  ...   valence  duration_min
# year                              ...
# 1921      0.895823      0.425661  ...  0.425495      3.831865
# 1922      0.939236      0.480000  ...  0.534056      2.798409
# 1923      0.976329      0.568462  ...  0.624788      2.972605
# 1924      0.935575      0.548654  ...  0.668574      3.141027
# 1925      0.965422      0.571890  ...  0.616430      3.068845
# ...            ...           ...  ...       ...           ...
# 2016      0.280290      0.599976  ...  0.430769      3.656679
# 2017      0.289916      0.612286  ...  0.414465      3.489060
# 2018      0.271941      0.664930  ...  0.447141      3.348652
# 2019      0.289298      0.644215  ...  0.465856      3.295552
# 2020      0.247374      0.673077  ...  0.482755      3.285244
#
# [100 rows x 15 columns]

# %%
data = df_year['acousticness']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Acousticness of Songs by Year')
plt.show()

# %%
data = df_year['danceability']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Danceability of Songs by Year')
plt.show()

# %%
data = df_year['energy']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Energy of Songs by Year')
plt.show()

# %%
data = df_year['explicit']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Percent of Songs Explicit by Year')
plt.show()

# %%
data = df_year['instrumentalness']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Instrumentalness of Songs by Year')
plt.show()

# %%
data = df_year['loudness']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Loudness of Songs by Year')
plt.show()

# %%
data = df_year['mode']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Percent of Songs in Major Mode by Year')
plt.show()

# %%
data = df_year['popularity']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Popularity of Songs by Year')
plt.show()

# %%
data = df_year['speechiness']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Speechiness of Songs by Year')
plt.show()

# %%
data = df_year['valence']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Valence of Songs by Year')
plt.show()

# %%
data = df_year['duration_min']
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1])
ax.bar(range(1921,2021), data)
ax.set_ylabel('Average of Songs')
ax.set_title('Average Duration of Songs by Year')
plt.show()
